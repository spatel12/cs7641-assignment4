# %%
"""
Solving FrozenLake8x8 environment using Policy iteration.
Author : Moustafa Alzantot (malzantot@ucla.edu)
Citation: https://medium.com/@m.alzantot/deep-reinforcement-learning-demysitifed-episode-2-policy-iteration-value-iteration-and-q-978f9e89ddaa
"""
import numpy as np
import gym
from gym import wrappers
import time as time
np.random.seed(42)


def run_episode(env, policy, gamma = 1.0, render = False):
    """ Runs an episode and return the total reward """
    obs = env.reset()
    total_reward = 0
    step_idx = 0
    while True:
        if render:
            env.render()
        obs, reward, done , _ = env.step(int(policy[obs]))
        total_reward += (gamma ** step_idx * reward)
        step_idx += 1
        if done:
            break
    return total_reward


def evaluate_policy(env, policy, gamma = 1.0, n = 100):
    scores = [run_episode(env, policy, gamma, False) for _ in range(n)]
    return scores

def extract_policy(v, gamma = 1.0):
    """ Extract the policy given a value-function """
    policy = np.zeros(1000)
    for s in range(1000):
        q_sa = np.zeros(3)
        for a in range(3):
            q_sa[a] = sum([p * (r + gamma * v[s_]) for p, s_, r, _ in  env.P[s][a]])
        policy[s] = np.argmax(q_sa)
    return policy

def compute_policy_v(env, policy, gamma=1.0):
    """ Iteratively evaluate the value-function under policy.
    Alternatively, we could formulate a set of linear equations in iterms of v[s] 
    and solve them to find the value function.
    """
    v = np.zeros(1000)
    eps = 1e-10
    #eps=0.1
    while True:
        prev_v = np.copy(v)
        for s in range(1000):
            policy_a = policy[s]
            v[s] = sum([p * (r + gamma * prev_v[s_]) for p, s_, r, _ in env.P[s][policy_a]])
        if (np.sum((np.fabs(prev_v - v))) <= eps):
            # value converged
            break
    return v

def policy_iteration(env, gamma = 1.0):
    """ Policy-Iteration algorithm """
    policy = np.random.choice(3, size=(1000))  # initialize a random policy
    max_iterations = 3000
    gamma = 1.0
    for i in range(max_iterations):
        old_policy_v = compute_policy_v(env, policy, gamma)
        new_policy = extract_policy(old_policy_v, gamma)
        if (np.all(policy == new_policy)):
            print ('Policy-Iteration converged at step %d.' %(i+1))
            break
        policy = new_policy
    return policy

# %%
env_name  = 'MountainCar-v0'
env = gym.make(env_name)
start = time.time()
optimal_policy = policy_iteration(env, gamma = 1.0)
print("Average time: " + str(((time.time() - start))))
scores = evaluate_policy(env, optimal_policy, gamma = 1.0)
print('Average scores = ', np.mean(scores))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-56ff0fcfb31d> in <module>
#       2 env = gym.make(env_name)
#       3 start = time.time()
# ----> 4 optimal_policy = policy_iteration(env, gamma = 1.0)
#       5 print("Average time: " + str(((time.time() - start))))
#       6 scores = evaluate_policy(env, optimal_policy, gamma = 1.0)
#
# <ipython-input-33-e8c3f093243d> in policy_iteration(env, gamma)
#      64     gamma = 1.0
#      65     for i in range(max_iterations):
# ---> 66         old_policy_v = compute_policy_v(env, policy, gamma)
#      67         new_policy = extract_policy(old_policy_v, gamma)
#      68         if (np.all(policy == new_policy)):
#
# <ipython-input-33-e8c3f093243d> in compute_policy_v(env, policy, gamma)
#      52         for s in range(1000):
#      53             policy_a = policy[s]
# ---> 54             v[s] = sum([p * (r + gamma * prev_v[s_]) for p, s_, r, _ in env.P[s][policy_a]])
#      55         if (np.sum((np.fabs(prev_v - v))) <= eps):
#      56             # value converged
#
# /opt/anaconda3/envs/ml/lib/python3.8/site-packages/gym/core.py in __getattr__(self, name)
#     221         if name.startswith('_'):
#     222             raise AttributeError("attempted to get missing private attribute '{}'".format(name))
# --> 223         return getattr(self.env, name)
#     224
#     225     @property
#
# AttributeError: 'MountainCarEnv' object has no attribute 'P'

# %%
env_name  = 'MountainCar-v0'
env = gym.make(env_name)

# %%
dir(env.unwrapped)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_height',
#  'action_space',
#  'close',
#  'force',
#  'get_keys_to_action',
#  'goal_position',
#  'goal_velocity',
#  'gravity',
#  'high',
#  'low',
#  'max_position',
#  'max_speed',
#  'metadata',
#  'min_position',
#  'np_random',
#  'observation_space',
#  'render',
#  'reset',
#  'reward_range',
#  'seed',
#  'spec',
#  'step',
#  'unwrapped',
#  'viewer']

# %%
dir(env.env)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_height',
#  'action_space',
#  'close',
#  'force',
#  'get_keys_to_action',
#  'goal_position',
#  'goal_velocity',
#  'gravity',
#  'high',
#  'low',
#  'max_position',
#  'max_speed',
#  'metadata',
#  'min_position',
#  'np_random',
#  'observation_space',
#  'render',
#  'reset',
#  'reward_range',
#  'seed',
#  'spec',
#  'step',
#  'unwrapped',
#  'viewer']
